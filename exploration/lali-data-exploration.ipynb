# %% [markdown]
# Questions that are arising:
# 1. Meaning of indident Type. The unique values for this column can be found in a cell below
# 2. How are the following related? Main ID, Incident ID, Incident Type

# %%
# load the data and see the columns
import pandas as pd
import numpy as np

migrantdf = pd.read_csv('../Missing_Migrants_Global_Figures_filtered.csv')
print("Columns in dataset: \n", migrantdf.columns)
# Out:
# Columns in dataset:
#  Index(['Unnamed: 0', 'Main ID', 'Incident ID', 'Incident Type',
#        'Region of Incident', 'Incident year', 'Reported Month',
#        'Number of Dead', 'Minimum Estimated Number of Missing',
#        'Total Number of Dead and Missing', 'Number of Survivors',
#        'Number of Females', 'Number of Males', 'Number of Children',
#        'Country of Origin', 'Region of Origin', 'Cause of Death',
#        'Migration route', 'Location of death', 'Information Source',
#        'Coordinates', 'UNSD Geographical Grouping', 'X', 'Y'],
#       dtype='object')

# %%
print("Sample row in the dataset: ", migrantdf.iloc[1])
# Out:
# Sample row in the dataset:  Unnamed: 0                                                                             1
# Main ID                                                                    2014.MMP00002
# Incident ID                                                                2014.MMP00002
# Incident Type                                                                   Incident
# Region of Incident                                                         North America
# Incident year                                                                       2014
# Reported Month                                                                   January
# Number of Dead                                                                         1
# Minimum Estimated Number of Missing                                                    0
# Total Number of Dead and Missing                                                       1
# Number of Survivors                                                                    0
# Number of Females                                                                      0
# Number of Males                                                                        0
# Number of Children                                                                     0
# Country of Origin                                                                Unknown
# Region of Origin                                           Latin America / Caribbean (P)
# Cause of Death                                                          Mixed or unknown
# Migration route                                                US-Mexico border crossing
# Location of death                      Pima Country Office of the Medical Examiner ju...
# Information Source                     Pima County Office of the Medical Examiner (PC...
# Coordinates                                                  POINT (-111.73756 31.59713)
# UNSD Geographical Grouping                                              Northern America
# X                                                                             -111.73756
# Y                                                                               31.59713
# Name: 1, dtype: object

# %% [markdown]
# Looks like each row is an incident, with 1+ recorded deaths

# %%
#  Most deadly routes

# migrantdf['Migration route']
migrantdf.groupby(['Migration route'])['Total Number of Dead and Missing'].sum()

migrantdf.groupby(['Migration route', 'Cause of Death'])['Total Number of Dead and Missing'].sum()
# Out:
# Migration route        Cause of Death
# Afghanistan to Iran    Accidental death                                                          321
#                        Drowning                                                                    7
#                        Harsh environmental conditions / lack of adequate shelter, food, water     32
#                        Mixed or unknown                                                           48
#                        Sickness / lack of access to adequate healthcare                          154
#                                                                                                 ...
# Western Mediterranean  Harsh environmental conditions / lack of adequate shelter, food, water     35
#                        Mixed or unknown                                                          173
#                        Sickness / lack of access to adequate healthcare                            9
#                        Vehicle accident / death linked to hazardous transport                     54
#                        Violence                                                                   32
# Name: Total Number of Dead and Missing, Length: 161, dtype: int64

# %%
print('Types of incidents: \n',migrantdf['Incident Type'].value_counts())

print("\nRows where we have incident type = split incident")
migrantdf[migrantdf['Incident Type']=='Split Incident'][0:3]
# Out:
# Types of incidents:
#  Incident                    10881
# Split Incident                205
# Cumulative Incident            82
# Incident, Split Incident        2
# Name: Incident Type, dtype: int64
#
# Rows where we have incident type = split incident
#      Unnamed: 0        Main ID  \
# 61           61  2014.MMP00062
# 126         126  2014.MMP00129
# 134         134  2014.MMP00137
#
#                                            Incident ID   Incident Type  \
# 61   2014.MMP0006263, 2014.MMP0006264, 2014.MMP0006...  Split Incident
# 126  2014.MMP00129131, 2014.MMP00129132, 2014.MMP00...  Split Incident
# 134  2014.MMP00137141, 2014.MMP00137142, 2014.MMP00...  Split Incident
#
#     Region of Incident  Incident year Reported Month  Number of Dead  \
# 61     Northern Africa           2014          April              10
# 126      Mediterranean           2014           June               2
# 134      Mediterranean           2014           July              12
#
#      Minimum Estimated Number of Missing  Total Number of Dead and Missing  \
# 61                                     0                                10
# 126                                    4                                 6
# 134                                  188                               200
#
#      ...                       Country of Origin  \
# 61   ...       Ethiopia, Eritrea, Unknown, Sudan
# 126  ...  Syrian Arab Republic, Morocco, Unknown
# 134  ...  Syrian Arab Republic, Eritrea, Unknown
#
#                                       Region of Origin  \
# 61            Eastern Africa, Unknown, Northern Africa
# 126  Western Asia, Northern Africa, Sub-Saharan Afr...
# 134              Western Asia, Eastern Africa, Unknown
#
#                                         Cause of Death  \
# 61   Harsh environmental conditions / lack of adequ...
# 126                                           Drowning
# 134                                           Drowning
#
#             Migration route  \
# 61   Sahara Desert crossing
# 126   Central Mediterranean
# 134   Central Mediterranean
#
#                                      Location of death    Information Source  \
# 61                              Sudanese-Libyan desert  Agence France Presse
# 126  Unspecified location between North Africa and ...          Yahoo! News
# 134           Off the coast of Tripoli (capsized boat)              Reuters
#
#             Coordinates UNSD Geographical Grouping     X        Y
# 61   POINT (22 23.3112)            Northern Africa  22.0  23.3112
# 126  POINT (13 36.1838)              Uncategorized  13.0  36.1838
# 134  POINT (13 32.9615)              Uncategorized  13.0  32.9615
#
# [3 rows x 24 columns]

# %%
migrantdf[migrantdf['Main ID']=='2014.MMP00137141']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Main ID, Incident ID, Incident Type, Region of Incident, Incident year, Reported Month, Number of Dead, Minimum Estimated Number of Missing, Total Number of Dead and Missing, Number of Survivors, Number of Females, Number of Males, Number of Children, Country of Origin, Region of Origin, Cause of Death, Migration route, Location of death, Information Source, Coordinates, UNSD Geographical Grouping, X, Y]
# Index: []
#
# [0 rows x 24 columns]

# %%
print("\nRows where we have incident type = Cumulative Incident")
migrantdf[migrantdf['Incident Type']=='Cumulative Incident']
# Out:
# Rows where we have incident type = Cumulative Incident
#              Main ID    Incident ID        Incident Type  Region of Incident  \
# 16     2014.MMP00017  2014.MMP00017  Cumulative Incident  South-eastern Asia
# 182    2014.MMP00187  2014.MMP00187  Cumulative Incident       North America
# 189    2014.MMP00194  2014.MMP00194  Cumulative Incident     Central America
# 232    2014.MMP00238  2014.MMP00238  Cumulative Incident     Central America
# 237    2014.MMP00243  2014.MMP00243  Cumulative Incident       Mediterranean
# ...              ...            ...                  ...                 ...
# 9255   2021.MMP00871  2021.MMP00871  Cumulative Incident       North America
# 9440    2021.MMP0160   2021.MMP0160  Cumulative Incident       North America
# 9625    2021.MMP0347   2021.MMP0347  Cumulative Incident       Mediterranean
# 10159   2021.MMP0881   2021.MMP0881  Cumulative Incident      Eastern Africa
# 10275  2022.MMP00081  2022.MMP00081  Cumulative Incident       North America
#
#       Website Date  Incident year Reported Month  Number of Dead  \
# 16      2014-02-02           2014       February               5
# 182     2014-08-27           2014         August              44
# 189     2014-08-31           2014         August              64
# 232     2014-10-31           2014        October              41
# 237     2014-11-26           2014       November               0
# ...            ...            ...            ...             ...
# 9255    2021-07-11           2021           July               6
# 9440    2021-11-11           2021       November              12
# 9625    2021-09-20           2021      September               2
# 10159   2021-12-31           2021       December              21
# 10275   2022-01-31           2022        January               8
#
#        Minimum Estimated Number of Missing  Total Number of Dead and Missing  \
# 16                                       0                                 5
# 182                                      0                                44
# 189                                      0                                64
# 232                                      0                                41
# 237                                      6                                 6
# ...                                    ...                               ...
# 9255                                     0                                 6
# 9440                                     0                                12
# 9625                                     0                                 2
# 10159                                   34                                55
# 10275                                    0                                 8
#
#        ...               Region of Origin  \
# 16     ...                  Southern Asia
# 182    ...  Latin America / Caribbean (P)
# 189    ...                Central America
# 232    ...                Central America
# 237    ...         Sub-Saharan Africa (P)
# ...    ...                            ...
# 9255   ...  Latin America / Caribbean (P)
# 9440   ...  Latin America / Caribbean (P)
# 9625   ...                        Unknown
# 10159  ...                 Eastern Africa
# 10275  ...  Latin America / Caribbean (P)
#
#                                          Cause of Death  \
# 16     Sickness / lack of access to adequate healthcare
# 182                                    Mixed or unknown
# 189                                    Mixed or unknown
# 232                                    Mixed or unknown
# 237                                            Drowning
# ...                                                 ...
# 9255                                   Mixed or unknown
# 9440                                   Mixed or unknown
# 9625                                           Drowning
# 10159                                          Drowning
# 10275                                  Mixed or unknown
#
#                  Migration route  \
# 16                           NaN
# 182    US-Mexico border crossing
# 189                          NaN
# 232                          NaN
# 237        Central Mediterranean
# ...                          ...
# 9255   US-Mexico border crossing
# 9440   US-Mexico border crossing
# 9625       Eastern Mediterranean
# 10159         Comoros to Mayotte
# 10275  US-Mexico border crossing
#
#                                        Location of death  \
# 16     Hat Yai hospital, 182 Ratthakan, Hat Yai, Hat ...
# 182                            Brooks County, Texas, USA
# 189                                      Mexico (likely)
# 232                          Various locations in Mexico
# 237                              Between Libya and Italy
# ...                                                  ...
# 9255      Various locations in Yuma County, Arizona, USA
# 9440    Various locations in Hudspeth County, Texas, USA
# 9625               Unspecified location in the Aegen Sea
# 10159   Unspecified location between Comoros and Mayotte
# 10275  Remains recovered around Falfurrias USBP check...
#
#                                       Information Source  \
# 16                                        Manager Online
# 182    Brooks County Sheriff’s Office, cited in Valle...
# 189    Permanent Mission of el Salvador to the UN in ...
# 232    Minitry of External Relations, Government of G...
# 237                                            IOM Italy
# ...                                                  ...
# 9255          Sheriff Leon Wilmot via Noticiasporelmundo
# 9440                                                 NBC
# 9625                                 Turkish Coast Guard
# 10159  Institut National de la Statistique, des Etude...
# 10275  EXCLUSIVE: Eight Migrants Found Dead in Januar...
#
#                             Coordinates UNSD Geographical Grouping  \
# 16        POINT (100.4674982 7.0167471)         South-eastern Asia
# 182        POINT (-98.233616 27.033656)           Northern America
# 189            POINT (-101.074 19.1452)            Central America
# 232            POINT (-102.553 23.6345)            Central America
# 237             POINT (12.9199 36.3151)              Uncategorized
# ...                                 ...                        ...
# 9255   POINT (-102.7255099 40.12453287)           Northern America
# 9440       POINT (-105.526907 31.34266)           Northern America
# 9625    POINT (12.54897854 33.01479981)              Uncategorized
# 10159      POINT (44.862988 -12.565108)             Eastern Africa
# 10275      POINT (-98.167336 27.025788)           Northern America
#
#                                            Article title Source Quality  \
# 16     ทำพิธีฝังหมู่โรฮิงญา 5 ศพ ป่วยตายระหว่างถูกกัก...            1.0
# 182                 Ranchers deal with immigrant traffic            5.0
# 189    Email from MILLMAN Joel 25.09.2014 in US-Mexic...            4.0
# 232    Deaths of Guatemalans in Mexico whose bodies w...            5.0
# 237    Migrants, mostly from Sub-Saharan Africa, cont...            4.0
# ...                                                  ...            ...
# 9255   Las muertes de inmigrantes ilegales se dispara...            1.0
# 9440   Migrants lead border officials to body of man ...            1.0
# 9625                                                 NaN            5.0
# 10159                                                NaN            5.0
# 10275                                                NaN            1.0
#
#                             URL
# 16     https://archive.vn/fHipt
# 182       http://bit.ly/1CfZmS9
# 189                         NaN
# 232                         NaN
# 237                         NaN
# ...                         ...
# 9255   https://archive.ph/aEdJp
# 9440   https://archive.vn/jU7er
# 9625   https://archive.ph/VPaQl
# 10159                       NaN
# 10275  https://archive.ph/fgdGh
#
# [82 rows x 25 columns]
